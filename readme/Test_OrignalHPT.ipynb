# %%
# !python pytorch/calculate_infers_smd.py infer_prob --cuda --workspace="./workspaces"\
--note_model='Note_pedal'\
--checkpoint_path='./workspaces/checkpoints/original_HPT/CRNN_note_F1=0.9677_pedal_F1=0.9186.pth'
# Out:
# Note_model Inference Start
# GPU number: 1
# 0 ./workspaces/hdf5s/smd/Beethoven_Op027No1-02_003_20090916-SMD.h5
# 1 ./workspaces/hdf5s/smd/Haydn_HobXVINo52-03_008_20110315-SMD.h5
# 2 ./workspaces/hdf5s/smd/Chopin_Op048No1_007_20100611-SMD.h5
# 3 ./workspaces/hdf5s/smd/Bartok_SZ080-01_002_20110315-SMD.h5
# 4 ./workspaces/hdf5s/smd/Haydn_HobXVINo52-02_008_20110315-SMD.h5
# 5 ./workspaces/hdf5s/smd/Bach_BWV875-01_002_20090916-SMD.h5
# 6 ./workspaces/hdf5s/smd/Bach_BWV888-02_008_20110315-SMD.h5
# 7 ./workspaces/hdf5s/smd/Chopin_Op010-03_007_20100611-SMD.h5
# 8 ./workspaces/hdf5s/smd/Liszt_AnnesDePelerinage-LectureDante_002_20090916-SMD.h5
# 9 ./workspaces/hdf5s/smd/Bach_BWV871-01_002_20090916-SMD.h5
# 10 ./workspaces/hdf5s/smd/Bach_BWV871-02_002_20090916-SMD.h5
# 11 ./workspaces/hdf5s/smd/Chopin_Op028-03_003_20100611-SMD.h5
# 12 ./workspaces/hdf5s/smd/Ravel_ValsesNoblesEtSentimentales_003_20090916-SMD.h5
# 13 ./workspaces/hdf5s/smd/Beethoven_Op031No2-03_002_20090916-SMD.h5
# ...

# %%
# !python pytorch/calculate_infers_smd.py infer_prob --cuda --workspace="./workspaces"\
--note_model='Note_pedal'\
--checkpoint_path='./workspaces/checkpoints/original_HPT/CRNN_note_F1=0.9677_pedal_F1=0.9186.pth'
# Out:
# Note_model Inference Start
# GPU number: 1
# 0 ./workspaces/hdf5s/maps/MAPS_MUS-chpn-e01_ENSTDkCl.h5
# 1 ./workspaces/hdf5s/maps/MAPS_MUS-bk_xmas1_ENSTDkCl.h5
# 2 ./workspaces/hdf5s/maps/MAPS_MUS-liz_et_trans5_ENSTDkCl.h5
# 3 ./workspaces/hdf5s/maps/MAPS_MUS-deb_clai_ENSTDkCl.h5
# 4 ./workspaces/hdf5s/maps/MAPS_MUS-liz_et6_ENSTDkCl.h5
# 5 ./workspaces/hdf5s/maps/MAPS_MUS-scn16_4_ENSTDkAm.h5
# 6 ./workspaces/hdf5s/maps/MAPS_MUS-scn16_4_ENSTDkCl.h5
# 7 ./workspaces/hdf5s/maps/MAPS_MUS-scn15_12_ENSTDkCl.h5
# 8 ./workspaces/hdf5s/maps/MAPS_MUS-ty_november_ENSTDkAm.h5
# 9 ./workspaces/hdf5s/maps/MAPS_MUS-schu_143_1_ENSTDkAm.h5
# 10 ./workspaces/hdf5s/maps/MAPS_MUS-chpn_op66_ENSTDkAm.h5
# 11 ./workspaces/hdf5s/maps/MAPS_MUS-chpn_op25_e4_ENSTDkAm.h5
# 12 ./workspaces/hdf5s/maps/MAPS_MUS-chpn_op7_1_ENSTDkAm.h5
# 13 ./workspaces/hdf5s/maps/MAPS_MUS-mz_333_3_ENSTDkCl.h5
# 14 ./workspaces/hdf5s/maps/MAPS_MUS-mz_333_2_ENSTDkCl.h5
# 15 ./workspaces/hdf5s/maps/MAPS_MUS-chpn-p14_ENSTDkAm.h5
# ...

# %%
# !python pytorch/calculate_scores.py exp.run_infer='notes' exp.num_workers=12 model.type='notes'\
     dataset.test_set='smd' # smd, maps, maestro
# Out:
# ...
# Evaluation Mode : NOTES
# Model Name      : Original HPT
# Test Set        : smd
# Using device    : cpu
# ...
# Original HPT: Est notes match Est velo
# [Done] Score Calculation Time: 36.19 sec
# ...
# velocity_mae: 18.8775
# velocity_std: 9.5447
# velocity_recall: 0.4786

# %%
# !python pytorch/calculate_scores.py exp.run_infer='notes' exp.num_workers=12 model.type='notes'\
     dataset.test_set='maps' # smd, maps, maestro
# Out:
# ...
# Evaluation Mode : NOTES
# Model Name      : Original HPT
# Test Set        : maps
# Using device    : cpu
# ...
# Original HPT: Est notes match Est velo
# [Done] Score Calculation Time: 36.38 sec
# ...
# velocity_mae: 13.5124
# velocity_std: 7.1698
# velocity_recall: 0.4782

# %%
# !python pytorch/calculate_scores.py exp.run_infer='notes' exp.num_workers=12 model.type='notes'\
     dataset.test_set='maestro' # smd, maps, maestro
# Out:
# ...
# Evaluation Mode : NOTES
# Model Name      : Original HPT
# Test Set        : maestro
# Using device    : cpu
# ...
# Original HPT: Est notes match Est velo
# [Done] Score Calculation Time: 423.45 sec
# ...
# velocity_mae: 3.4438
# velocity_std: 3.4129
# velocity_recall: 0.7976

# %%
# !python pytorch/calculate_scores.py exp.run_infer='notes' exp.num_workers=12 model.type='notes'\
     dataset.test_set='maestro' # smd, maps, maestro
# Out:
# ...
# Evaluation Mode : NOTES
# Model Name      : Original HPT
# Test Set        : maestro
# Using device    : cpu
# ...
# Original HPT: Est notes match Est velo
# [Done] Score Calculation Time: 426.64 sec
# ...
# velocity_mae: 3.4438
# velocity_std: 3.4129
# velocity_recall: 0.8970
